# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("Processed Data/Good stations for toltip map.csv") 
df.head()
# Out:
#    Unnamed: 0        date  ZAFIT JUNCTION  YEROHAM,DAM  \
# 0           0  1949-01-01             NaN          NaN
# 1           1  1950-01-01             NaN          NaN
# 2           2  1951-01-01             NaN          NaN
# 3           3  1952-01-01             NaN         90.0
# 4           4  1953-01-01             NaN        112.9
#
#    YEROHAM S BOQER ROAD KM 42  UPPER MA'ALE AQRABIM  SEDOM ASCENT  \
# 0                         NaN            131.000000           NaN
# 1                         NaN             46.300000           NaN
# 2                         NaN             73.000000           NaN
# 3                        85.0             59.000000           NaN
# 4                       157.0             58.819697           NaN
#
#    SAYYARIM JUNCTION  ROAD 40 - NAHAL ZIN  CROSSING  ORON JUNCTION  ...  \
# 0                NaN                            NaN            NaN  ...
# 1                NaN                            NaN            NaN  ...
# 2                NaN                            NaN            NaN  ...
# 3                NaN                            NaN           75.0  ...
# 4                NaN                            NaN           89.4  ...
#
#    KM 71 ARAVA RD  HAR HORESHA  HAR HATIRA ASCENT  HAMESHAR  \
# 0             NaN          NaN                NaN       NaN
# 1             NaN          NaN                NaN       NaN
# 2             NaN          NaN                NaN       NaN
# 3             NaN          NaN               80.0       NaN
# 4             NaN          NaN               96.2       NaN
#
#    HAMAKHTESH HAGADOL  HAMAKHTESH HAGADOL WEST RIM  EN GEDI RD OPP MEZADA  \
# 0                 NaN                          NaN                    NaN
# 1                 NaN                          NaN                    NaN
# 2                 NaN                          NaN                    NaN
# 3                 NaN                          NaN                    NaN
# 4                 NaN                          NaN                    NaN
#
#    BEER MENUHA KM 101  ASHALIM NIZZANA ROAD KM 53  ARVAT YAFRUQ KM 825
# 0                 NaN                         NaN                 72.0
# 1                 NaN                         NaN                 30.5
# 2                 NaN                         NaN                 38.5
# 3                 NaN                         NaN                 44.5
# 4                 NaN                         NaN                 48.0
#
# [5 rows x 28 columns]

# %%
# Convert the date column to string if it's not already
date_column_name = 'date'
df[date_column_name] = df[date_column_name].astype(str)

# # # Set the date column as the index
df.set_index(date_column_name, inplace=True)
df = df.drop(df.columns[0],axis=1)
# # Extract the first year from the date column
df['year'] = df.index.str.split('-').str[0].astype(int)
df
# Out:
#             ZAFIT JUNCTION  YEROHAM,DAM  YEROHAM S BOQER ROAD KM 42  \
# date
# 1949-01-01             NaN          NaN                         NaN
# 1950-01-01             NaN          NaN                         NaN
# 1951-01-01             NaN          NaN                         NaN
# 1952-01-01             NaN         90.0                        85.0
# 1953-01-01             NaN        112.9                       157.0
# ...                    ...          ...                         ...
# 2017-01-01            60.5         90.0                        84.0
# 2018-01-01            67.0         69.0                        72.5
# 2019-01-01            81.0        135.5                       153.5
# 2020-01-01            42.0         28.5                        20.0
# 2021-01-01            30.0         55.0                        72.0
#
#             UPPER MA'ALE AQRABIM  SEDOM ASCENT  SAYYARIM JUNCTION  \
# date
# 1949-01-01            131.000000           NaN                NaN
# 1950-01-01             46.300000           NaN                NaN
# 1951-01-01             73.000000           NaN                NaN
# 1952-01-01             59.000000           NaN                NaN
# 1953-01-01             58.819697           NaN                NaN
# ...                          ...           ...                ...
# 2017-01-01             11.300000          47.5          23.500000
# 2018-01-01             52.000000          69.0          25.500000
# 2019-01-01             78.500000          51.5          91.500000
# 2020-01-01             13.500000          26.0          15.500000
# 2021-01-01             58.819697          30.0          22.942857
#
#             ROAD 40 - NAHAL ZIN  CROSSING  ORON JUNCTION  NIZZANA  \
# date
# 1949-01-01                            NaN            NaN      NaN
# 1950-01-01                            NaN            NaN      NaN
# 1951-01-01                            NaN            NaN      NaN
# 1952-01-01                            NaN           75.0      NaN
# 1953-01-01                            NaN           89.4      NaN
# ...                                   ...            ...      ...
# 2017-01-01                           59.5           87.0     51.5
# 2018-01-01                           81.5           55.5     66.5
# 2019-01-01                          165.5          128.4    106.0
# 2020-01-01                           21.5           25.0     23.5
# 2021-01-01                           60.0           35.0     57.0
#
#             NAHAL ZIN MOUTH  ...  HAR HORESHA  HAR HATIRA ASCENT  HAMESHAR  \
# date                         ...
# 1949-01-01              NaN  ...          NaN                NaN       NaN
# 1950-01-01              NaN  ...          NaN                NaN       NaN
# 1951-01-01              NaN  ...          NaN                NaN       NaN
# 1952-01-01              NaN  ...          NaN               80.0       NaN
# 1953-01-01              NaN  ...          NaN               96.2       NaN
# ...                     ...  ...          ...                ...       ...
# 2017-01-01             33.0  ...    88.076923               67.5      54.0
# 2018-01-01             49.0  ...    88.076923               75.5      79.0
# 2019-01-01             47.0  ...    88.076923              136.5     102.5
# 2020-01-01             18.0  ...    88.076923               16.5      11.5
# 2021-01-01             32.0  ...    88.076923               89.3      33.0
#
#             HAMAKHTESH HAGADOL  HAMAKHTESH HAGADOL WEST RIM  \
# date
# 1949-01-01                 NaN                          NaN
# 1950-01-01                 NaN                          NaN
# 1951-01-01                 NaN                          NaN
# 1952-01-01                 NaN                          NaN
# 1953-01-01                 NaN                          NaN
# ...                        ...                          ...
# 2017-01-01               123.5                         70.5
# 2018-01-01                51.5                         72.0
# 2019-01-01                87.0                        164.5
# 2020-01-01                20.0                         32.0
# 2021-01-01                30.0                         55.0
#
#             EN GEDI RD OPP MEZADA  BEER MENUHA KM 101  \
# date
# 1949-01-01                    NaN                 NaN
# 1950-01-01                    NaN                 NaN
# 1951-01-01                    NaN                 NaN
# 1952-01-01                    NaN                 NaN
# 1953-01-01                    NaN                 NaN
# ...                           ...                 ...
# 2017-01-01                   52.0                23.5
# 2018-01-01                   43.5                29.5
# 2019-01-01                   54.5               116.5
# 2020-01-01                   34.0                 5.5
# 2021-01-01                   17.0                16.0
#
#             ASHALIM NIZZANA ROAD KM 53  ARVAT YAFRUQ KM 825  year
# date
# 1949-01-01                         NaN            72.000000  1949
# 1950-01-01                         NaN            30.500000  1950
# 1951-01-01                         NaN            38.500000  1951
# 1952-01-01                         NaN            44.500000  1952
# 1953-01-01                         NaN            48.000000  1953
# ...                                ...                  ...   ...
# 2017-01-01                        82.0            26.500000  2017
# 2018-01-01                        67.5            24.500000  2018
# 2019-01-01                       122.5            82.500000  2019
# 2020-01-01                        38.0            31.947761  2020
# 2021-01-01                        55.0            29.000000  2021
#
# [73 rows x 27 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Assuming df is your DataFrame with a 'date' column and other columns
date_column_name = 'date'

# Specify the columns for which you want to create graphs
columns_to_plot = df.columns[0:25]  # Assuming you want to plot the first 9 columns

# Create subplots
fig, axs = plt.subplots(5,5, figsize=(17, 10))

# Flatten the axs array to iterate over subplots
axs = axs.flatten()

# Iterate over the specified columns
for ax, column_name in zip(axs, columns_to_plot):
    # Calculate the average of the current column
    
    data = df[['year', column_name]].dropna()
    average_column = df[column_name].mean()
    # Plot a bar graph for the current column
    ax.bar(data['year'], (data[column_name]- average_column ), color='blue')

    # Fit a linear regression line
    z = np.polyfit(data['year'], data[column_name] - average_column, 1)
    p = np.poly1d(z)

    # Plotting the trend line
    ax.plot(data['year'], p(data['year']), color='red', linestyle='--', linewidth=2)
    #ax.plot(kind='bar', edgecolor='white', linewidth=3)
    # Customize the subplot
    #numpy.around(a, decimals=0, out=None)
    slope =np.around(z[0], decimals=2, out=None) 
    ax.set_title(f'{column_name} :{slope }')

    ax.set_xlabel('Year')
    ax.set_ylabel('(Yearly-avrge)[mm]')

# Adjust layout
plt.tight_layout()


plt.savefig("Processed Data/annual Rine relative to the average.jpg")

# %%
# Show the plot
plt.show()

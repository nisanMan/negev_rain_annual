# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
df = pd.read_csv("Processed Data/Good stations for toltip map.csv") 

df.head()
# Out:
#    Unnamed: 0        date  ZAFIT JUNCTION  YEROHAM,DAM  \
# 0           0  1949-01-01             NaN          NaN
# 1           1  1950-01-01             NaN          NaN
# 2           2  1951-01-01             NaN          NaN
# 3           3  1952-01-01             NaN         90.0
# 4           4  1953-01-01             NaN        112.9
#
#    YEROHAM S BOQER ROAD KM 42  UPPER MA'ALE AQRABIM  SEDOM ASCENT  \
# 0                         NaN            131.000000           NaN
# 1                         NaN             46.300000           NaN
# 2                         NaN             73.000000           NaN
# 3                        85.0             59.000000           NaN
# 4                       157.0             58.819697           NaN
#
#    SAYYARIM JUNCTION  ROAD 40 - NAHAL ZIN  CROSSING  ORON JUNCTION  ...  \
# 0                NaN                            NaN            NaN  ...
# 1                NaN                            NaN            NaN  ...
# 2                NaN                            NaN            NaN  ...
# 3                NaN                            NaN           75.0  ...
# 4                NaN                            NaN           89.4  ...
#
#    KM 71 ARAVA RD  HAR HORESHA  HAR HATIRA ASCENT  HAMESHAR  \
# 0             NaN          NaN                NaN       NaN
# 1             NaN          NaN                NaN       NaN
# 2             NaN          NaN                NaN       NaN
# 3             NaN          NaN               80.0       NaN
# 4             NaN          NaN               96.2       NaN
#
#    HAMAKHTESH HAGADOL  HAMAKHTESH HAGADOL WEST RIM  EN GEDI RD OPP MEZADA  \
# 0                 NaN                          NaN                    NaN
# 1                 NaN                          NaN                    NaN
# 2                 NaN                          NaN                    NaN
# 3                 NaN                          NaN                    NaN
# 4                 NaN                          NaN                    NaN
#
#    BEER MENUHA KM 101  ASHALIM NIZZANA ROAD KM 53  ARVAT YAFRUQ KM 825
# 0                 NaN                         NaN                 72.0
# 1                 NaN                         NaN                 30.5
# 2                 NaN                         NaN                 38.5
# 3                 NaN                         NaN                 44.5
# 4                 NaN                         NaN                 48.0
#
# [5 rows x 28 columns]

# %%
# Convert the date column to string if it's not already
date_column_name = 'date'
df[date_column_name] = df[date_column_name].astype(str)

# # # Set the date column as the index
df.set_index(date_column_name, inplace=True)
df = df.drop(df.columns[0],axis=1)
# # Extract the first year from the date column
df['year'] = df.index.str.split('-').str[0].astype(int)
df.head()
# Out:
#             ZAFIT JUNCTION  YEROHAM,DAM  YEROHAM S BOQER ROAD KM 42  \
# date
# 1949-01-01             NaN          NaN                         NaN
# 1950-01-01             NaN          NaN                         NaN
# 1951-01-01             NaN          NaN                         NaN
# 1952-01-01             NaN         90.0                        85.0
# 1953-01-01             NaN        112.9                       157.0
#
#             UPPER MA'ALE AQRABIM  SEDOM ASCENT  SAYYARIM JUNCTION  \
# date
# 1949-01-01            131.000000           NaN                NaN
# 1950-01-01             46.300000           NaN                NaN
# 1951-01-01             73.000000           NaN                NaN
# 1952-01-01             59.000000           NaN                NaN
# 1953-01-01             58.819697           NaN                NaN
#
#             ROAD 40 - NAHAL ZIN  CROSSING  ORON JUNCTION  NIZZANA  \
# date
# 1949-01-01                            NaN            NaN      NaN
# 1950-01-01                            NaN            NaN      NaN
# 1951-01-01                            NaN            NaN      NaN
# 1952-01-01                            NaN           75.0      NaN
# 1953-01-01                            NaN           89.4      NaN
#
#             NAHAL ZIN MOUTH  ...  HAR HORESHA  HAR HATIRA ASCENT  HAMESHAR  \
# date                         ...
# 1949-01-01              NaN  ...          NaN                NaN       NaN
# 1950-01-01              NaN  ...          NaN                NaN       NaN
# 1951-01-01              NaN  ...          NaN                NaN       NaN
# 1952-01-01              NaN  ...          NaN               80.0       NaN
# 1953-01-01              NaN  ...          NaN               96.2       NaN
#
#             HAMAKHTESH HAGADOL  HAMAKHTESH HAGADOL WEST RIM  \
# date
# 1949-01-01                 NaN                          NaN
# 1950-01-01                 NaN                          NaN
# 1951-01-01                 NaN                          NaN
# 1952-01-01                 NaN                          NaN
# 1953-01-01                 NaN                          NaN
#
#             EN GEDI RD OPP MEZADA  BEER MENUHA KM 101  \
# date
# 1949-01-01                    NaN                 NaN
# 1950-01-01                    NaN                 NaN
# 1951-01-01                    NaN                 NaN
# 1952-01-01                    NaN                 NaN
# 1953-01-01                    NaN                 NaN
#
#             ASHALIM NIZZANA ROAD KM 53  ARVAT YAFRUQ KM 825  year
# date
# 1949-01-01                         NaN                 72.0  1949
# 1950-01-01                         NaN                 30.5  1950
# 1951-01-01                         NaN                 38.5  1951
# 1952-01-01                         NaN                 44.5  1952
# 1953-01-01                         NaN                 48.0  1953
#
# [5 rows x 27 columns]

# %%
df.index.name = 'date'

df = df.reset_index()
df["date"] = pd.to_datetime(df["date"].str.split('-').str[0] + "-01-01")

columns_to_drop = 23
df.drop(df.columns[columns_to_drop], axis=1, inplace=True)
df.drop(['SAYYARIM JUNCTION', 'NIZZANA','NAHAL OMER KM 129','MIZPE ELAT','HAR HORESHA',], axis=1)

df.head()
# Out:
#         date  ZAFIT JUNCTION  YEROHAM,DAM  YEROHAM S BOQER ROAD KM 42  \
# 0 1949-01-01             NaN          NaN                         NaN
# 1 1950-01-01             NaN          NaN                         NaN
# 2 1951-01-01             NaN          NaN                         NaN
# 3 1952-01-01             NaN         90.0                        85.0
# 4 1953-01-01             NaN        112.9                       157.0
#
#    UPPER MA'ALE AQRABIM  SEDOM ASCENT  SAYYARIM JUNCTION  \
# 0            131.000000           NaN                NaN
# 1             46.300000           NaN                NaN
# 2             73.000000           NaN                NaN
# 3             59.000000           NaN                NaN
# 4             58.819697           NaN                NaN
#
#    ROAD 40 - NAHAL ZIN  CROSSING  ORON JUNCTION  NIZZANA  ...  KM 71 ARAVA RD  \
# 0                            NaN            NaN      NaN  ...             NaN
# 1                            NaN            NaN      NaN  ...             NaN
# 2                            NaN            NaN      NaN  ...             NaN
# 3                            NaN           75.0      NaN  ...             NaN
# 4                            NaN           89.4      NaN  ...             NaN
#
#    HAR HORESHA  HAR HATIRA ASCENT  HAMESHAR  HAMAKHTESH HAGADOL  \
# 0          NaN                NaN       NaN                 NaN
# 1          NaN                NaN       NaN                 NaN
# 2          NaN                NaN       NaN                 NaN
# 3          NaN               80.0       NaN                 NaN
# 4          NaN               96.2       NaN                 NaN
#
#    HAMAKHTESH HAGADOL WEST RIM  BEER MENUHA KM 101  \
# 0                          NaN                 NaN
# 1                          NaN                 NaN
# 2                          NaN                 NaN
# 3                          NaN                 NaN
# 4                          NaN                 NaN
#
#    ASHALIM NIZZANA ROAD KM 53  ARVAT YAFRUQ KM 825  year
# 0                         NaN                 72.0  1949
# 1                         NaN                 30.5  1950
# 2                         NaN                 38.5  1951
# 3                         NaN                 44.5  1952
# 4                         NaN                 48.0  1953
#
# [5 rows x 27 columns]

# %%
df = df.drop(['SAYYARIM JUNCTION', 'NIZZANA','NAHAL OMER KM 129','MIZPE ELAT','HAR HORESHA',], axis=1)

# %%
hit_map = df.copy()
hit_map.head()
# Out:
#         date  ZAFIT JUNCTION  YEROHAM,DAM  YEROHAM S BOQER ROAD KM 42  \
# 0 1949-01-01             NaN          NaN                         NaN
# 1 1950-01-01             NaN          NaN                         NaN
# 2 1951-01-01             NaN          NaN                         NaN
# 3 1952-01-01             NaN         90.0                        85.0
# 4 1953-01-01             NaN        112.9                       157.0
#
#    UPPER MA'ALE AQRABIM  SEDOM ASCENT  ROAD 40 - NAHAL ZIN  CROSSING  \
# 0            131.000000           NaN                            NaN
# 1             46.300000           NaN                            NaN
# 2             73.000000           NaN                            NaN
# 3             59.000000           NaN                            NaN
# 4             58.819697           NaN                            NaN
#
#    ORON JUNCTION  NAHAL ZIN MOUTH  NAHAL ZAVOA CROSS  ...  KOKHAV  \
# 0            NaN              NaN                NaN  ...     NaN
# 1            NaN              NaN                NaN  ...     NaN
# 2            NaN              NaN                NaN  ...     NaN
# 3           75.0              NaN              110.0  ...    92.0
# 4           89.4              NaN              144.1  ...    94.0
#
#    KM 71 ARAVA RD  HAR HATIRA ASCENT  HAMESHAR  HAMAKHTESH HAGADOL  \
# 0             NaN                NaN       NaN                 NaN
# 1             NaN                NaN       NaN                 NaN
# 2             NaN                NaN       NaN                 NaN
# 3             NaN               80.0       NaN                 NaN
# 4             NaN               96.2       NaN                 NaN
#
#    HAMAKHTESH HAGADOL WEST RIM  BEER MENUHA KM 101  \
# 0                          NaN                 NaN
# 1                          NaN                 NaN
# 2                          NaN                 NaN
# 3                          NaN                 NaN
# 4                          NaN                 NaN
#
#    ASHALIM NIZZANA ROAD KM 53  ARVAT YAFRUQ KM 825  year
# 0                         NaN                 72.0  1949
# 1                         NaN                 30.5  1950
# 2                         NaN                 38.5  1951
# 3                         NaN                 44.5  1952
# 4                         NaN                 48.0  1953
#
# [5 rows x 22 columns]

# %% [markdown]
# # An empty matrix for a heat map

# %%
at_last_years = 1
def calculate_slope(data, column_name, start_year, end_year):
    
    if start_year >= end_year-1-at_last_years :
        return 0
    # Convert the 'date' column to datetime and create a 'year' column
    data['year'] = pd.to_datetime(data['date'], format='%Y-%m-%d').dt.year

    # Filter the data based on the specified range of years
    selected_data = data.loc[(data['year'] >= start_year) & (data['year'] <= end_year)]

    if selected_data[column_name].isna().any():
        return 0 


    # Remove rows with NaN values in the selected column
    selected_data = selected_data[['year', column_name]].dropna()

    # Calculate the average of the selected column
    average_column = selected_data[column_name].mean()

    # Fit a linear regression line
    z = np.polyfit(selected_data['year'], selected_data[column_name] - average_column, 1)
    
    # Return the slope of the trend line
    return np.around(z[0], decimals=4, out=None)

# %% [markdown]
# # for tasting

# %%
first_NaN = df.apply(pd.Series.first_valid_index)

# %%
first_NaN
# Out:
# date                              0
# ZAFIT JUNCTION                    5
# YEROHAM,DAM                       3
# YEROHAM S BOQER ROAD KM 42        3
# UPPER MA'ALE AQRABIM              0
# SEDOM ASCENT                      6
# ROAD 40 - NAHAL ZIN  CROSSING    11
# ORON JUNCTION                     3
# NAHAL ZIN MOUTH                  12
# NAHAL ZAVOA CROSS                 3
# NAHAL HIYYON                      9
# MAKHTESH RAMON                    7
# KOKHAV                            3
# KM 71 ARAVA RD                   10
# HAR HATIRA ASCENT                 3
# HAMESHAR                          7
# HAMAKHTESH HAGADOL               12
# HAMAKHTESH HAGADOL WEST RIM      12
# BEER MENUHA KM 101                9
# ASHALIM NIZZANA ROAD KM 53        9
# ARVAT YAFRUQ KM 825               0
# year                              0
# dtype: int64

# %% [markdown]
# # An empty matrix for a heat map

# %%
# Display the DataFrame
end_year = 2021
start_year = 1950
# Create a date range for the index
index_range = pd.date_range(start=f'{start_year}-01-01', end=f'{end_year}-01-01', freq='AS')
# Create a DataFrame with zeros
ampte = pd.DataFrame(0, index=index_range, columns=index_range)
ampte
# Out:
#             1950-01-01  1951-01-01  1952-01-01  1953-01-01  1954-01-01  \
# 1950-01-01           0           0           0           0           0
# 1951-01-01           0           0           0           0           0
# 1952-01-01           0           0           0           0           0
# 1953-01-01           0           0           0           0           0
# 1954-01-01           0           0           0           0           0
# ...                ...         ...         ...         ...         ...
# 2017-01-01           0           0           0           0           0
# 2018-01-01           0           0           0           0           0
# 2019-01-01           0           0           0           0           0
# 2020-01-01           0           0           0           0           0
# 2021-01-01           0           0           0           0           0
#
#             1955-01-01  1956-01-01  1957-01-01  1958-01-01  1959-01-01  ...  \
# 1950-01-01           0           0           0           0           0  ...
# 1951-01-01           0           0           0           0           0  ...
# 1952-01-01           0           0           0           0           0  ...
# 1953-01-01           0           0           0           0           0  ...
# 1954-01-01           0           0           0           0           0  ...
# ...                ...         ...         ...         ...         ...  ...
# 2017-01-01           0           0           0           0           0  ...
# 2018-01-01           0           0           0           0           0  ...
# 2019-01-01           0           0           0           0           0  ...
# 2020-01-01           0           0           0           0           0  ...
# 2021-01-01           0           0           0           0           0  ...
#
#             2012-01-01  2013-01-01  2014-01-01  2015-01-01  2016-01-01  \
# 1950-01-01           0           0           0           0           0
# 1951-01-01           0           0           0           0           0
# 1952-01-01           0           0           0           0           0
# 1953-01-01           0           0           0           0           0
# 1954-01-01           0           0           0           0           0
# ...                ...         ...         ...         ...         ...
# 2017-01-01           0           0           0           0           0
# 2018-01-01           0           0           0           0           0
# 2019-01-01           0           0           0           0           0
# 2020-01-01           0           0           0           0           0
# 2021-01-01           0           0           0           0           0
#
#             2017-01-01  2018-01-01  2019-01-01  2020-01-01  2021-01-01
# 1950-01-01           0           0           0           0           0
# 1951-01-01           0           0           0           0           0
# 1952-01-01           0           0           0           0           0
# 1953-01-01           0           0           0           0           0
# 1954-01-01           0           0           0           0           0
# ...                ...         ...         ...         ...         ...
# 2017-01-01           0           0           0           0           0
# 2018-01-01           0           0           0           0           0
# 2019-01-01           0           0           0           0           0
# 2020-01-01           0           0           0           0           0
# 2021-01-01           0           0           0           0           0
#
# [72 rows x 72 columns]

# %% [markdown]
# ## Function calculates slope by year and column name

# %%
def calculate_sum_of_years(df,station_name):
    """
    Calculate the sum of corresponding years for each element in the DataFrame.

    Parameters:
    - df: pandas DataFrame

    Returns:
    - result_df: pandas DataFrame with values representing the sum of corresponding years
    """
    num_rows, num_columns = df.shape
    result_df = pd.DataFrame(index=df.index, columns=df.columns, dtype=int)

    for i in range(num_rows):
        for j in range(num_columns):
            result_df.iloc[i, j]= calculate_slope(hit_map,station_name , df.index[i].year, df.columns[j].year)#df.index[i].year + df.columns[j].year

    return result_df

# %%
reversed_cmap = ListedColormap(sns.color_palette('coolwarm', n_colors=256)[::-1])

def onegraf(station_name):
    result_df = calculate_sum_of_years(ampte,station_name)
    # Create a reversed 'bwr' colormap

    # Assuming 'result_df' is your DataFrame with calculated values
    ax = sns.heatmap(result_df.transpose(), vmin=-1, vmax=1, cmap=reversed_cmap)
    
    ax.invert_yaxis()

    # Set ticks at every five years
    years = result_df.columns.year
    ax.set_xticks(range(0, len(years), 10))
    ax.set_xticklabels(years[::10], rotation=45, ha='right')

    ax.set_yticks(range(0, len(years), 10))
    ax.set_yticklabels(years[::10])

    ax.set_title(station_name)  # Add column name as the titl])

    # Show the plot
onegraf("ARVAT YAFRUQ KM 825" )
plt.savefig('Processed Data/hit map exmple.png')

# %%
# Assuming you already have 'reversed_cmap' and 'onegraf' function defined

# Create a 4x5 subplot grid
fig, axs = plt.subplots(4, 5, figsize=(20, 16))

# Loop over desired columns and generate heatmaps
for i, column_name in enumerate(hit_map.columns[1:21]):  # Adjust to select the first 20 columns
    # Calculate row and column indices
    row_index = i // 5
    col_index = i % 5

    # Set the current axis in the subplot grid
    plt.sca(axs[row_index, col_index])

    # Call the function to generate the heatmap
    onegraf(column_name)

plt.tight_layout()  # Adjust layout for better spacing
#plt.show()
plt.savefig('Processed Data/hit map full.png')

# %%
#At least a decade of measurements
at_last_years = 10

# %%
fig, axs = plt.subplots(4, 5, figsize=(20, 16))

# Loop over desired columns and generate heatmaps
for i, column_name in enumerate(hit_map.columns[1:21]):  # Adjust to select the first 20 columns
    # Calculate row and column indices
    row_index = i // 5
    col_index = i % 5

    # Set the current axis in the subplot grid
    plt.sca(axs[row_index, col_index])

    # Call the function to generate the heatmap
    onegraf(column_name)

plt.tight_layout()  # Adjust layout for better spacing
# plt.show()
plt.savefig('Processed Data/hit map full 10 years.png')
